# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
model_config = {"learning" : 0.001, "batch_size":64, "activation_function" : "relu", "optimizer" : "adam"}

# %%
model_config["learning"]
# Out:
# 0.001

# %%
temp_dict = {1:"one", 2:"two"}

# %%
temp_dict[1]
# Out:
# 'one'

# %%
d2 = {True: "true"}

# %%
d2[True]
# Out:
# 'true'

# %%
d2[1]
# Out:
# 'true'

# %%
d2[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 d2[2]
#
# KeyError: 2

# %%
user_profile = { "user_name": "amit", "account_level": 5, "subscription_active": True, "recent_courses": ["python", "ML", "pyTorch"], "login_coordinates":(55.34,87.00),

                 "permissions" : {"read", "write"}, "model_metrics": {"accuracy": 0.98, "loss" : 0.02}, "account_level":7}

# %%
user_profile
# Out:
# {'user_name': 'amit',
#  'account_level': 7,
#  'subscription_active': True,
#  'recent_courses': ['python', 'ML', 'pyTorch'],
#  'login_coordinates': (55.34, 87.0),
#  'permissions': {'read', 'write'},
#  'model_metrics': {'accuracy': 0.98, 'loss': 0.02}}

# %%
user_profile["login_coordinates"]
# Out:
# (55.34, 87.0)

# %%
user_profile["recent_courses"][2]
# Out:
# 'pyTorch'

# %%
user_profile["subscription_active"]  = False

# %%
user_profile.
# Out:
# {'user_name': 'amit',
#  'account_level': 7,
#  'subscription_active': False,
#  'recent_courses': ['python', 'ML', 'pyTorch'],
#  'login_coordinates': (55.34, 87.0),
#  'permissions': {'read', 'write'},
#  'model_metrics': {'accuracy': 0.98, 'loss': 0.02}}

# %%
user_profile['contact'] = "9934XXXXXX"

# %%
user_profile
# Out:
# {'user_name': 'amit',
#  'account_level': 7,
#  'subscription_active': False,
#  'recent_courses': ['python', 'ML', 'pyTorch'],
#  'login_coordinates': (55.34, 87.0),
#  'permissions': {'read', 'write'},
#  'model_metrics': {'accuracy': 0.98, 'loss': 0.02},
#  'contact': '9934XXXXXX'}

# %%
user_profile['contact']
# Out:
# '9934XXXXXX'

# %%
del user_profile['contact']

# %%
user_profile
# Out:
# {'user_name': 'amit',
#  'account_level': 7,
#  'subscription_active': False,
#  'recent_courses': ['python', 'ML', 'pyTorch'],
#  'login_coordinates': (55.34, 87.0),
#  'permissions': {'read', 'write'},
#  'model_metrics': {'accuracy': 0.98, 'loss': 0.02}}

# %%
user_profile.pop('permissions')
# Out:
# {'read', 'write'}

# %%
list(user_profile.keys())
# Out:
# ['user_name',
#  'account_level',
#  'subscription_active',
#  'recent_courses',
#  'login_coordinates',
#  'model_metrics']

# %%
list(user_profile.values())
# Out:
# ['amit',
#  7,
#  False,
#  ['python', 'ML', 'pyTorch'],
#  (55.34, 87.0),
#  {'accuracy': 0.98, 'loss': 0.02}]

# %%
user_profile.items()
# Out:
# dict_items([('user_name', 'amit'), ('account_level', 7), ('subscription_active', False), ('recent_courses', ['python', 'ML', 'pyTorch']), ('login_coordinates', (55.34, 87.0)), ('model_metrics', {'accuracy': 0.98, 'loss': 0.02})])

# %%
l = list(user_profile.items())

# %%
l
# Out:
# [('user_name', 'amit'),
#  ('account_level', 7),
#  ('subscription_active', False),
#  ('recent_courses', ['python', 'ML', 'pyTorch']),
#  ('login_coordinates', (55.34, 87.0)),
#  ('model_metrics', {'accuracy': 0.98, 'loss': 0.02})]

# %%
l[2]
# Out:
# ('subscription_active', False)

# %%
l[2][0]
# Out:
# 'subscription_active'

# %%
user_profile['model_metrics']['loss']
# Out:
# 0.02
