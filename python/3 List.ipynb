# %% [markdown]
# # List

# %%
first_list = [4,6,5,3,8,66,33,445,67]

# %%
type(first_list)
# Out:
# list

# %%
first_list[4]
# Out:
# 8

# %%
first_list[0]
# Out:
# 4

# %%
first_list[2:5]
# Out:
# [5, 3, 8]

# %%
first_list[-1]
# Out:
# 67

# %%
first_list[-5]
# Out:
# 8

# %%
first_list
# Out:
# [4, 6, 5, 3, 8, 66, 33, 445, 67]

# %%
first_list[::-1]
# Out:
# [67, 445, 33, 66, 8, 3, 5, 6, 4]

# %%
first_list[::2]
# Out:
# [4, 5, 8, 33, 67]

# %%
first_list[2:8:2]
# Out:
# [5, 8, 33]

# %%
s = " Amit"

# %%
second_list = [4,6,3,6, "ML", "Deep Learning", " GEN AI" , [4,5,3,7]]

# %%
second_list[2]
# Out:
# 3

# %%
first_list + second_list
# Out:
# [4,
#  6,
#  5,
#  3,
#  8,
#  66,
#  33,
#  445,
#  67,
#  4,
#  6,
#  3,
#  6,
#  'ML',
#  'Deep Learning',
#  ' GEN AI',
#  [4, 5, 3, 7]]

# %%
first_list - second_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 first_list - second_list
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
first_list * 3
# Out:
# [4,
#  6,
#  5,
#  3,
#  8,
#  66,
#  33,
#  445,
#  67,
#  4,
#  6,
#  5,
#  3,
#  8,
#  66,
#  33,
#  445,
#  67,
#  4,
#  6,
#  5,
#  3,
#  8,
#  66,
#  33,
#  445,
#  67]

# %%
first_list
# Out:
# [4, 6, 5, 3, 8, 66, 33, 445, 67]

# %%
len(first_list)
# Out:
# 9

# %%
first_list.append(10)

# %%
first_list
# Out:
# [4, 6, 5, 3, 8, 66, 33, 445, 67, 10]

# %%
first_list.append(20)

# %%
first_list
# Out:
# [4, 6, 5, 3, 8, 66, 33, 445, 67, 10, 20]

# %%
first_list.append("Amit")

# %%
first_list
# Out:
# [4, 6, 5, 3, 8, 66, 33, 445, 67, 10, 20, 'Amit']

# %%
first_list.extend("Amit")

# %%
first_list
# Out:
# [4, 6, 5, 3, 8, 66, 33, 445, 67, 10, 20, 'Amit', 'A', 'm', 'i', 't']

# %%
first_list.extend([5,7,3])

# %%
first_list
# Out:
# [4, 6, 5, 3, 8, 66, 33, 445, 67, 10, 20, 'Amit', 'A', 'm', 'i', 't', 5, 7, 3]

# %%
first_list.extend(["Amit", "Dhakad"])

# %%
first_list
# Out:
# [4, 6, 5, 3, 8, 66, 33, 445, 67]

# %%
first_list.insert(3,55)

# %%
first_list
# Out:
# [4, 6, 5, 55, 3, 8, 66, 33, 445, 67]

# %%
first_list.insert(-1, 68)

# %%
first_list
# Out:
# [4, 6, 5, 55, 3, 8, 66, 33, 445, 68, 67]

# %%
first_list.pop()
# Out:
# 67

# %%
first_list
# Out:
# [4, 6, 5, 55, 3, 8, 66, 33, 445, 68]

# %%
first_list.pop(3)
# Out:
# 55

# %%
first_list
# Out:
# [4, 6, 5, 3, 8, 66, 33, 445, 68]

# %%
first_list.append(5)

# %%
first_list
# Out:
# [4, 6, 5, 3, 8, 66, 33, 445, 68, 5]

# %%
first_list.remove(6)

# %%
first_list
# Out:
# [4, 5, 3, 8, 66, 33, 445, 68, 5]

# %%
first_list.remove(5)

# %%
first_list
# Out:
# [4, 3, 8, 66, 33, 445, 68, 5]

# %%
first_list[::-1]
# Out:
# [68, 445, 33, 66, 8, 3, 4]

# %%
first_list
# Out:
# [4, 3, 8, 66, 33, 445, 68]

# %%
first_list.reverse()

# %%
first_list
# Out:
# [68, 445, 33, 66, 8, 3, 4]

# %%
first_list.index(33)
# Out:
# 2

# %%
first_list.append(33)

# %%
first_list
# Out:
# [68, 445, 33, 66, 8, 3, 4, 33]

# %%
first_list.index(33)
# Out:
# 2

# %%
first_list.count(68)
# Out:
# 1

# %%
first_list.count(33)
# Out:
# 2

# %%
second_list
# Out:
# [4, 6, 3, 6, 'ML', 'Deep Learning', ' GEN AI', [4, 5, 3, 7]]

# %%
second_list[2] = 5

# %%
second_list
# Out:
# [4, 6, 5, 6, 'ML', 'Deep Learning', ' GEN AI', [4, 5, 3, 7]]

# %%
second_list[-1][1] = 3

# %%
second_list
# Out:
# [4, 6, 5, 6, 'ML', 'Deep Learning', ' GEN AI', [4, 3, 3, 7]]

# %%
second_list[6] = "Genrative AI"

# %%
second_list
# Out:
# [4, 6, 5, 6, 'ML', 'Deep Learning', 'Genrative AI', [4, 3, 3, 7]]

# %%
second_list[6][1] = "E"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 second_list[6][1] = "E"
#
# TypeError: 'str' object does not support item assignment

# %%
s = " Gen AI"

# %%
s
# Out:
# ' Gen AI'

# %%
s[3] = " E "
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 s[3] = " E "
#
# TypeError: 'str' object does not support item assignment

# %%
s = " GENERATIVE AI"

# %%
s
# Out:
# ' GENERATIVE AI'

# %%
second_list
# Out:
# [4, 6, 5, 6, 'ML', 'Deep Learning', 'Genrative AI', [4, 3, 3, 7]]

# %%
s
# Out:
# ' GENERATIVE AI'

# %%
s = s.replace('E', 'e')

# %%
s
# Out:
# ' GeNeRATIVe AI'

# %%
third_list = [4,6,3,8,6,1,9,0]

# %%
third_list.sort()

# %%
third_list
# Out:
# [0, 1, 3, 4, 6, 6, 8, 9]

# %%
third_list.sort(reverse = True)

# %%
third_list
# Out:
# [9, 8, 6, 6, 4, 3, 1, 0]
