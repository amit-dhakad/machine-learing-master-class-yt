# %%
l = [1,3,5,6,7,8,9,5]

# %%
l1 = []

# %%
for i in l:
    l1.append(i**2)

# %%
l1
# Out:
# [1, 9, 25, 36, 49, 64, 81, 25]

# %%
[ i**2 for i in l1]
# Out:
# [1, 81, 625, 1296, 2401, 4096, 6561, 625]

# %%
pixels = [0,128,255]

[ i /255 for i in pixels]
# Out:
# [0.0, 0.5019607843137255, 1.0]

# %%
age = {5,15,20,7,34,65,12,34, 18}

{i for i in age if i >= 18}
# Out:
# {18, 20, 34, 65}

# %%
models = {"RandomForest" : 0.85, "XGBoost": 0.94, "NeuralNet": 0.98}

{ key: value for (key,value) in models.items() if value <  0.94}
# Out:
# {'RandomForest': 0.85}

# %%
matrix = [[1,2,3],[4,5,6]]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
[num for row in matrix for num in row]
# Out:
# [1, 2, 3, 4, 5, 6]
