# %%
t = (2,5,4,7,8,9, "Amit", 4.5, 6+5j, True)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 2

# %%
t[6]
# Out:
# 'Amit'

# %%
t[9]
# Out:
# True

# %%
t[34]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 t[34]
#
# IndexError: tuple index out of range

# %%
t[-1]
# Out:
# True

# %%
t[:: -1]
# Out:
# (True, (6+5j), 4.5, 'Amit', 9, 8, 7, 4, 5, 2)

# %%
t[0] = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t[0] = 20
#
# TypeError: 'tuple' object does not support item assignment

# %%
t
# Out:
# (2, 5, 4, 7, 8, 9, 'Amit', 4.5, (6+5j), True)

# %%
t = t[:: -1]

# %%
t
# Out:
# (True, (6+5j), 4.5, 'Amit', 9, 8, 7, 4, 5, 2)

# %%
t.count(8)
# Out:
# 1

# %%
t1 = (4,4,4,5,6,6,3,2,2)

# %%
t1.count(4)
# Out:
# 3

# %%
t1.index(5)
# Out:
# 3

# %%
temp = {}

# %%
type(temp)
# Out:
# dict

# %%
temp = {4,3,6,37,6,44,65}

# %%
type(temp)
# Out:
# set

# %%
temp = {"name": "amit"}

# %%
type(temp)
# Out:
# dict

# %%
s = {1,1,1,4,3,4,5,6,7,7,6,5}

# %%
s
# Out:
# {1, 3, 4, 5, 6, 7}

# %%
s = {"Amit", "amit", "amit"}

# %%
s
# Out:
# {'Amit', 'amit'}

# %%
s = {4,5,3,[5,6,7]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 s = {4,5,3,[5,6,7]}
#
# TypeError: unhashable type: 'list'

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s = {5,4,6, (3,4,5,6)}

# %%
s.add(7)

# %%
s
# Out:
# {(3, 4, 5, 6), 4, 5, 6, 7}

# %%
s.add([4,8,8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 s.add([4,8,8])
#
# TypeError: unhashable type: 'list'

# %%
s.add(7)

# %%
s
# Out:
# {(3, 4, 5, 6), 4, 5, 6, 7}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
l1 = [6,8,3,5,3,4,6,2,4,6]

# %%
set(l1)
# Out:
# {2, 3, 4, 5, 6, 8}

# %%
list(set(l1))
# Out:
# [2, 3, 4, 5, 6, 8]

# %%
s = {44,553,5532,1,2,34,666,789}

# %%
s
# Out:
# {1, 2, 34, 44, 553, 666, 789, 5532}

# %%
set(s)
# Out:
# {1, 2, 34, 44, 553, 666, 789, 5532}
